# %% [markdown]
# here we will cluster the embeddings to see if there is any similarities between them

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

from sklearn.decomposition import PCA

# %%
# %matplotlib inline

# %% [markdown]
# ## Read deepwalk 64 embedding

# %%
vecsize = 64
idx = 0

# %%
features = pd.read_csv(
    "data/min_hetionet/test/embedding_{}_{}.txt".format(vecsize, idx),
    sep=" ", skiprows=1,
    names=["uid"] + ["f{}".format(i) for i in range(vecsize)]
)

# %%
features.shape
# Out:
# (7927, 65)

# %%
features.head()
# Out:
#     uid        f0        f1        f2        f3        f4        f5        f6  \
# 0  7324  0.424142  2.057529  2.150354 -1.964922 -0.957505  5.427593 -2.124011
# 1  6959  0.960617  2.266797  2.294675 -3.552197  6.926412 -0.751194 -0.446336
# 2  6410  4.730375 -1.576859 -2.161227 -3.447428 -5.780465  5.726500 -1.936984
# 3  5929 -0.741860 -0.560861  5.339453 -0.595004 -2.708641 -1.778100 -4.780436
# 4  6305  1.299903 -1.940370 -2.188239  2.613826  1.144808  1.529212  4.657269
#
#          f7        f8    ...          f54       f55       f56       f57  \
# 0 -5.059958  4.391842    ...    -6.505708 -1.930992 -0.213860  2.902412
# 1 -5.394247  0.258741    ...    -4.399741  2.619867 -3.753803 -0.367113
# 2 -2.280269  1.794731    ...     1.259608 -1.428305  1.736320 -0.445753
# 3  0.398455 -1.219101    ...    -4.096083 -2.499942 -0.779885  0.202663
# 4 -3.104798 -2.172987    ...    -7.022854  7.174292 -2.310328  4.432360
#
#         f58       f59       f60       f61       f62       f63
# 0 -6.539911 -3.800288  2.269024  1.881055  5.683529 -0.839482
# 1 -6.181104 -0.731330  5.883546 -2.194875 -3.054283 -4.622406
# 2 -3.646091  2.913816 -2.992223 -0.504564  1.245656 -8.235349
# 3 -0.462629  5.672264  1.017156  1.501361  1.662245 -8.636725
# 4  3.285754  3.411851  0.881052 -5.351818  4.123768 -4.677237
#
# [5 rows x 65 columns]

# %% [markdown]
# ---

# %%
mtrx = features.drop("uid", axis=1)

# %%
mtrx.head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0  0.424142  2.057529  2.150354 -1.964922 -0.957505  5.427593 -2.124011
# 1  0.960617  2.266797  2.294675 -3.552197  6.926412 -0.751194 -0.446336
# 2  4.730375 -1.576859 -2.161227 -3.447428 -5.780465  5.726500 -1.936984
# 3 -0.741860 -0.560861  5.339453 -0.595004 -2.708641 -1.778100 -4.780436
# 4  1.299903 -1.940370 -2.188239  2.613826  1.144808  1.529212  4.657269
#
#          f7        f8        f9    ...          f54       f55       f56  \
# 0 -5.059958  4.391842  2.804703    ...    -6.505708 -1.930992 -0.213860
# 1 -5.394247  0.258741  2.839302    ...    -4.399741  2.619867 -3.753803
# 2 -2.280269  1.794731  0.180242    ...     1.259608 -1.428305  1.736320
# 3  0.398455 -1.219101 -1.531608    ...    -4.096083 -2.499942 -0.779885
# 4 -3.104798 -2.172987 -2.745302    ...    -7.022854  7.174292 -2.310328
#
#         f57       f58       f59       f60       f61       f62       f63
# 0  2.902412 -6.539911 -3.800288  2.269024  1.881055  5.683529 -0.839482
# 1 -0.367113 -6.181104 -0.731330  5.883546 -2.194875 -3.054283 -4.622406
# 2 -0.445753 -3.646091  2.913816 -2.992223 -0.504564  1.245656 -8.235349
# 3  0.202663 -0.462629  5.672264  1.017156  1.501361  1.662245 -8.636725
# 4  4.432360  3.285754  3.411851  0.881052 -5.351818  4.123768 -4.677237
#
# [5 rows x 64 columns]

# %%
num_groups = 8

# %%
cluster = KMeans(n_clusters=num_groups).fit_predict(mtrx)

# %%
cluster
# Out:
# array([3, 3, 3, ..., 0, 0, 0], dtype=int32)

# %% [markdown]
# ---

# %%
res = pd.concat(
    [pd.Series(cluster).to_frame("cluster"), features], axis=1
)

# %%
res.shape
# Out:
# (7927, 66)

# %%
res.head()
# Out:
#    cluster   uid        f0        f1        f2        f3        f4        f5  \
# 0        3  7324  0.424142  2.057529  2.150354 -1.964922 -0.957505  5.427593
# 1        3  6959  0.960617  2.266797  2.294675 -3.552197  6.926412 -0.751194
# 2        3  6410  4.730375 -1.576859 -2.161227 -3.447428 -5.780465  5.726500
# 3        3  5929 -0.741860 -0.560861  5.339453 -0.595004 -2.708641 -1.778100
# 4        3  6305  1.299903 -1.940370 -2.188239  2.613826  1.144808  1.529212
#
#          f6        f7    ...          f54       f55       f56       f57  \
# 0 -2.124011 -5.059958    ...    -6.505708 -1.930992 -0.213860  2.902412
# 1 -0.446336 -5.394247    ...    -4.399741  2.619867 -3.753803 -0.367113
# 2 -1.936984 -2.280269    ...     1.259608 -1.428305  1.736320 -0.445753
# 3 -4.780436  0.398455    ...    -4.096083 -2.499942 -0.779885  0.202663
# 4  4.657269 -3.104798    ...    -7.022854  7.174292 -2.310328  4.432360
#
#         f58       f59       f60       f61       f62       f63
# 0 -6.539911 -3.800288  2.269024  1.881055  5.683529 -0.839482
# 1 -6.181104 -0.731330  5.883546 -2.194875 -3.054283 -4.622406
# 2 -3.646091  2.913816 -2.992223 -0.504564  1.245656 -8.235349
# 3 -0.462629  5.672264  1.017156  1.501361  1.662245 -8.636725
# 4  3.285754  3.411851  0.881052 -5.351818  4.123768 -4.677237
#
# [5 rows x 66 columns]

# %% [markdown]
# ---

# %%
nodes = pd.read_csv("data/min_hetionet/minhet_nodes.tsv", sep='\t')

# %%
nodes.head()
# Out:
#    node_uid node_id    name het_type
# 0         0      10    NAT2     Gene
# 1         1     100     ADA     Gene
# 2         2   10000    AKT3     Gene
# 3         3   10005   ACOT8     Gene
# 4         4   10007  GNPDA1     Gene

# %%
final = (res
    .rename(columns={"uid": "node_uid"})
    .merge(
        nodes.drop("node_id", axis=1),
        how="inner", on="node_uid"
    )
)

# %%
final.head()
# Out:
#    cluster  node_uid        f0        f1        f2        f3        f4  \
# 0        3      7324  0.424142  2.057529  2.150354 -1.964922 -0.957505
# 1        3      6959  0.960617  2.266797  2.294675 -3.552197  6.926412
# 2        3      6410  4.730375 -1.576859 -2.161227 -3.447428 -5.780465
# 3        3      5929 -0.741860 -0.560861  5.339453 -0.595004 -2.708641
# 4        3      6305  1.299903 -1.940370 -2.188239  2.613826  1.144808
#
#          f5        f6        f7    ...          f56       f57       f58  \
# 0  5.427593 -2.124011 -5.059958    ...    -0.213860  2.902412 -6.539911
# 1 -0.751194 -0.446336 -5.394247    ...    -3.753803 -0.367113 -6.181104
# 2  5.726500 -1.936984 -2.280269    ...     1.736320 -0.445753 -3.646091
# 3 -1.778100 -4.780436  0.398455    ...    -0.779885  0.202663 -0.462629
# 4  1.529212  4.657269 -3.104798    ...    -2.310328  4.432360  3.285754
#
#         f59       f60       f61       f62       f63          name  het_type
# 0 -3.800288  2.269024  1.881055  5.683529 -0.839482    Crizotinib  Compound
# 1 -0.731330  5.883546 -2.194875 -3.054283 -4.622406     Dasatinib  Compound
# 2  2.913816 -2.992223 -0.504564  1.245656 -8.235349  Thioridazine  Compound
# 3  5.672264  1.017156  1.501361  1.662245 -8.636725     Menadione  Compound
# 4  3.411851  0.881052 -5.351818  4.123768 -4.677237   Vinblastine  Compound
#
# [5 rows x 68 columns]

# %%
tmp = final[["cluster", "node_uid", "name", "het_type"]]

# %%
tmp.head()
# Out:
#    cluster  node_uid          name  het_type
# 0        3      7324    Crizotinib  Compound
# 1        3      6959     Dasatinib  Compound
# 2        3      6410  Thioridazine  Compound
# 3        3      5929     Menadione  Compound
# 4        3      6305   Vinblastine  Compound

# %%
tmp.groupby("cluster")["het_type"].value_counts()
# Out:
# cluster  het_type
# 0        Gene        3501
#          Compound     291
#          Anatomy      162
# 1        Anatomy      236
#          Disease      133
#          Compound       7
#          Gene           1
# 2        Compound     497
#          Gene         311
# 3        Compound     285
# 4        Gene         700
# 5        Compound     429
# 6        Gene         675
#          Compound       8
# 7        Gene         684
#          Compound       7
# Name: het_type, dtype: int64

# %% [markdown]
# ---

# %%
pca = PCA(2)

# %%
projected = pca.fit_transform(features.drop("uid", axis=1))

# %%
projected.shape
# Out:
# (7927, 2)

# %%
plt.scatter(
    projected[:, 0], projected[:, 1],
    c=cluster, edgecolor='none', alpha=0.5
)

plt.colorbar()

# %% [markdown]
# ---

# %%
tmp.head()
# Out:
#    cluster  node_uid          name  het_type
# 0        3      7324    Crizotinib  Compound
# 1        3      6959     Dasatinib  Compound
# 2        3      6410  Thioridazine  Compound
# 3        3      5929     Menadione  Compound
# 4        3      6305   Vinblastine  Compound

# %%
info = pd.concat(
    [
        pd.DataFrame(projected, columns=["pca0", "pca1"]),
        tmp
    ], axis=1
)

# %%
info.head()
# Out:
#        pca0      pca1  cluster  node_uid          name  het_type
# 0  3.607805 -1.804192        3      7324    Crizotinib  Compound
# 1  3.242420 -1.293130        3      6959     Dasatinib  Compound
# 2  0.928369  1.820969        3      6410  Thioridazine  Compound
# 3  2.434372 -0.101360        3      5929     Menadione  Compound
# 4  3.356972 -0.224086        3      6305   Vinblastine  Compound

# %% [markdown]
# ---

# %%
small = info.query("het_type == 'Compound'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar();

# %%
small = info.query("het_type == 'Gene'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar();

# %%
small = info.query("het_type == 'Disease'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar();

# %%
small = info.query("het_type == 'Anatomy'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar();

# %%
a = info.query("pca0 < 0 and pca1 < 0")

# %%
a.head()
# Out:
#         pca0      pca1  cluster  node_uid         name  het_type
# 57 -0.274292 -1.816563        6      6335   Ivermectin  Compound
# 59 -0.209745 -1.605103        6      6114  Vinorelbine  Compound
# 61 -1.479809 -0.093936        6      5985   Lovastatin  Compound
# 65 -2.318916 -0.225241        6      6806  Fluvastatin  Compound
# 73 -0.735102 -0.685797        6      7043      Danazol  Compound

# %%
a["het_type"].value_counts()
# Out:
# Gene        2077
# Anatomy      398
# Compound     247
# Disease      133
# Name: het_type, dtype: int64

# %%
info.query("pca0 > 0 or pca1 > 0")["het_type"].value_counts()
# Out:
# Gene        3795
# Compound    1277
# Name: het_type, dtype: int64

# %% [markdown]
# ---

# %%
info.head()
# Out:
#        pca0      pca1  cluster  node_uid          name  het_type
# 0  3.607773 -1.805288        6      7324    Crizotinib  Compound
# 1  3.242395 -1.294174        6      6959     Dasatinib  Compound
# 2  0.928388  1.822031        6      6410  Thioridazine  Compound
# 3  2.434376 -0.102702        6      5929     Menadione  Compound
# 4  3.356995 -0.223157        7      6305   Vinblastine  Compound

# %%
small = info.query("het_type == 'Gene' or het_type == 'Compound'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar()

# %%
small = info.query("het_type == 'Disease' or het_type == 'Anatomy'")

plt.scatter(
    small["pca0"], small["pca1"],
    c=small["cluster"], edgecolor='none', alpha=0.5
)

plt.colorbar()
