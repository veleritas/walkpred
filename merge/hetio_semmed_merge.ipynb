# %% [markdown]
# # Harmonize SemmedDB with a Hetionet using UMLS CUIs
#
# Executive decision after discussion: overwrite hetio types with semmed types. for any remaining hetio types without cuis in semmed, just change the type to the most common one
#
# Keep any hetio nodes with missing cuis in hetio id space

# %%
import pandas as pd
import re

# %% [markdown]
# ## Read Hetionet nodes

# %%
hnodes = pd.read_csv("hetionet/hetio_nodes.tsv", sep='\t')

# %%
hnodes.shape
# Out:
# (58700, 4)

# %%
hnodes.head()
# Out:
#       hetio_id                               name             het_type  \
# 0      DB00795                      Sulfasalazine             Compound
# 1      DB00795                      Sulfasalazine             Compound
# 2      DB00795                      Sulfasalazine             Compound
# 3  N0000000151  Histamine H2 Receptor Antagonists  Pharmacologic Class
# 4    100996420                            DNM1P50                 Gene
#
#              cui
# 0  UMLS:C0036078
# 1  UMLS:C0699547
# 2  UMLS:C4255898
# 3  UMLS:C2757005
# 4      100996420

# %% [markdown]
# ---

# %% [markdown]
# ## Read Semmed nodes

# %%
def is_cui(s):
    return re.match(r'^C[0-9]{7}$', s) is not None

# %%
snodes = (pd
    .read_csv("../semmed/data/node_map.tsv", sep='\t')
    .drop("node_uid", axis=1)
    .assign(
        cui = lambda df: df["node_id"].map(
            lambda v: "UMLS:{}".format(v) if is_cui(v) else v
        )
    )
    .drop("node_id", axis=1)
    .rename(columns={"ntype": "sem_type"})
)

# %%
snodes.head()
# Out:
#                                            name           sem_type  \
# 0            1,2-Dipalmitoylphosphatidylcholine  Chemicals & Drugs
# 1             1,4-alpha-Glucan Branching Enzyme  Chemicals & Drugs
# 2                        1-Carboxyglutamic Acid  Chemicals & Drugs
# 3                   1-Methyl-3-isobutylxanthine  Chemicals & Drugs
# 4  1-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine  Chemicals & Drugs
#
#              cui
# 0  UMLS:C0000039
# 1  UMLS:C0000052
# 2  UMLS:C0000084
# 3  UMLS:C0000096
# 4  UMLS:C0000097

# %%
snodes["cui"].str.startswith("UMLS").value_counts()
# Out:
# True     210382
# False         7
# Name: cui, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Determine the most common SemmedDB node type for each Hetionet node type

# %%
ntype_map = (hnodes
    .merge(snodes, how="inner", on="cui")
    .drop(["name_x", "name_y"], axis=1)
    .groupby("het_type")
    .apply(lambda df: df["sem_type"].value_counts().axes[0][0])
    .to_frame("sem_type")
    .reset_index()
             
    .append(
        pd.DataFrame(
            [("Pathway", "Pathway")],
            columns=["het_type", "sem_type"]
        )
    )
    .reset_index(drop=True)
)

# %%
ntype_map
# Out:
#                het_type                     sem_type
# 0               Anatomy                      Anatomy
# 1    Biological Process                   Physiology
# 2    Cellular Component                      Anatomy
# 3              Compound            Chemicals & Drugs
# 4               Disease                    Disorders
# 5                  Gene  Genes & Molecular Sequences
# 6    Molecular Function                   Physiology
# 7   Pharmacologic Class            Chemicals & Drugs
# 8           Side Effect                    Disorders
# 9               Symptom                    Disorders
# 10              Pathway                      Pathway

# %% [markdown]
# ---

# %% [markdown]
# ## Determine how Hetionet nodes will be identified in the merged network
#
# Rules:
# * Use all CUIs which are in SemmedDB if they exist
# * Otherwise use the original Hetionet id

# %%
all_scuis = set(snodes["cui"])

hnode_map = (hnodes
    .assign(in_sem = lambda df: df["cui"].map(lambda v: v in all_scuis))
    .groupby("hetio_id")
    .apply(
        lambda df: df.query("in_sem") if df["in_sem"].any() else df.head(1)
    )
    .reset_index(drop=True)
    .assign(final_id = lambda df:
        df[["hetio_id", "cui", "in_sem"]].apply(
            lambda r: r["cui"] if r["in_sem"] else r["hetio_id"],
            axis=1
        )
    )
    .drop("cui", axis=1)
)

# %%
hnode_map.shape
# Out:
# (48277, 5)

# %%
hnode_map.head()
# Out:
#   hetio_id  name het_type  in_sem       final_id
# 0        1  A1BG     Gene    True  UMLS:C1412045
# 1       10  NAT2     Gene    True  UMLS:C0796518
# 2      100   ADA     Gene    True  UMLS:C1412179
# 3     1000  CDH2     Gene    True  UMLS:C1413277
# 4    10000  AKT3     Gene    True  UMLS:C1332074

# %% [markdown]
# ---

# %%
hnode_map["in_sem"].value_counts()
# Out:
# True     27123
# False    21154
# Name: in_sem, dtype: int64

# %%
hnode_map["hetio_id"].nunique()
# Out:
# 47031

# %% [markdown]
# ### How many identifiers per hetio id (as a %)

# %%
(hnode_map
    .groupby("hetio_id")
    .size()
    .value_counts(normalize=True)
    .multiply(100)
    .sort_index()
)
# Out:
# 1     98.394676
# 2      1.158810
# 3      0.236015
# 4      0.087177
# 5      0.048904
# 6      0.019136
# 7      0.021263
# 8      0.006379
# 9      0.010631
# 10     0.004253
# 12     0.004253
# 14     0.004253
# 16     0.002126
# 18     0.002126
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Assign semantic types to the node map

# %%
fin_hnode_map = (hnode_map
    .merge(
        snodes.drop("name", axis=1), how="left",
        left_on="final_id", right_on="cui"
    )
    .drop("cui", axis=1)
    .rename(columns={"sem_type": "orig_stype"})
    .merge(ntype_map, how="left", on="het_type")
    .assign(
        fin_type = lambda df: df["orig_stype"].fillna(df["sem_type"])
    )
    .drop(["orig_stype", "sem_type"], axis=1)
)

# %%
fin_hnode_map.head()
# Out:
#   hetio_id  name het_type  in_sem       final_id                     fin_type
# 0        1  A1BG     Gene    True  UMLS:C1412045  Genes & Molecular Sequences
# 1       10  NAT2     Gene    True  UMLS:C0796518  Genes & Molecular Sequences
# 2      100   ADA     Gene    True  UMLS:C1412179  Genes & Molecular Sequences
# 3     1000  CDH2     Gene    True  UMLS:C1413277  Genes & Molecular Sequences
# 4    10000  AKT3     Gene    True  UMLS:C1332074  Genes & Molecular Sequences

# %%
fin_hnode_map.to_csv(
    "hetionet/fin_hetio_nodes.tsv", sep='\t', index=False
)

# %% [markdown]
# ---

# %% [markdown]
# ## Map Hetionet edges to SemmedDB edges
#
# Adjust the semantics of the edges accordingly, and simplify where possible.

# %%
hedges = (pd
    .read_csv("data/hetionet/hetnet_edges.csv", sep=',')
    .rename(columns={
        ":START_ID": "start_id",
        ":END_ID": "end_id",
        ":TYPE": "het_etype"
    })
)

# %%
hedges.shape
# Out:
# (2249052, 3)

# %%
hedges.head()
# Out:
#          start_id      end_id          het_etype
# 0            8568  GO:0042254  PARTICIPATES_GpBP
# 1  UBERON:0002450       51316      EXPRESSES_AeG
# 2            4893    PC7_8430  PARTICIPATES_GpPW
# 3  UBERON:0002185       55186      EXPRESSES_AeG
# 4          119504  GO:0033047  PARTICIPATES_GpBP

# %% [markdown]
# ---

# %% [markdown]
# ### Convert Hetio nodes to their final node types

# %%
het_etypes = (hedges
    .merge(
        fin_hnode_map[["hetio_id", "het_type", "fin_type"]],
        how="inner", left_on="start_id", right_on="hetio_id"
    )
    .drop("hetio_id", axis=1)
    .rename(columns={
        "het_type": "start_htype",
        "fin_type": "start_ftype"
    })
       
    .merge(
        fin_hnode_map[["hetio_id", "het_type", "fin_type"]],
        how="inner", left_on="end_id", right_on="hetio_id"
    )
    .drop("hetio_id", axis=1)
    .rename(columns={
        "het_type": "end_htype",
        "fin_type": "end_ftype"
    })
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
het_etypes.head()
# Out:
#   start_id      end_id          het_etype start_htype  \
# 0     8568  GO:0042254  PARTICIPATES_GpBP        Gene
# 1     6201  GO:0042254  PARTICIPATES_GpBP        Gene
# 2     6223  GO:0042254  PARTICIPATES_GpBP        Gene
# 3     6202  GO:0042254  PARTICIPATES_GpBP        Gene
# 4    65003  GO:0042254  PARTICIPATES_GpBP        Gene
#
#                    start_ftype           end_htype   end_ftype
# 0  Genes & Molecular Sequences  Biological Process  Physiology
# 1  Genes & Molecular Sequences  Biological Process  Physiology
# 2  Genes & Molecular Sequences  Biological Process  Physiology
# 3  Genes & Molecular Sequences  Biological Process  Physiology
# 4  Genes & Molecular Sequences  Biological Process  Physiology

# %% [markdown]
# ### Group hetio edges by node types and count edges

# %%
h_etype_count = (het_etypes
    .groupby(["start_ftype", "end_ftype"])
    ["het_etype"]
    .value_counts()
    .to_frame("count")
    .reset_index()
)

# %%
h_etype_count
# Out:
#                     start_ftype                    end_ftype  \
# 0                       Anatomy  Genes & Molecular Sequences
# 1                       Anatomy  Genes & Molecular Sequences
# 2                       Anatomy  Genes & Molecular Sequences
# 3             Chemicals & Drugs                      Anatomy
# 4             Chemicals & Drugs            Chemicals & Drugs
# 5             Chemicals & Drugs            Chemicals & Drugs
# 6             Chemicals & Drugs                    Disorders
# 7             Chemicals & Drugs  Genes & Molecular Sequences
# 8             Chemicals & Drugs  Genes & Molecular Sequences
# 9             Chemicals & Drugs  Genes & Molecular Sequences
# 10            Chemicals & Drugs                    Phenomena
# 11            Chemicals & Drugs                    Phenomena
# 12            Chemicals & Drugs                   Physiology
# 13                    Disorders                      Anatomy
# 14                    Disorders            Chemicals & Drugs
# 15                    Disorders                    Disorders
# 16                    Disorders                    Disorders
# 17                    Disorders                    Disorders
# 18                    Disorders  Genes & Molecular Sequences
# 19                    Disorders  Genes & Molecular Sequences
# 20                    Disorders  Genes & Molecular Sequences
# 21                    Disorders  Genes & Molecular Sequences
# 22                    Disorders                   Physiology
# 23                    Disorders                   Physiology
# 24  Genes & Molecular Sequences                      Anatomy
# 25  Genes & Molecular Sequences                      Anatomy
# 26  Genes & Molecular Sequences            Chemicals & Drugs
# 27  Genes & Molecular Sequences                    Disorders
# 28  Genes & Molecular Sequences  Genes & Molecular Sequences
# 29  Genes & Molecular Sequences  Genes & Molecular Sequences
# 30  Genes & Molecular Sequences  Genes & Molecular Sequences
# 31  Genes & Molecular Sequences                Living Beings
# 32  Genes & Molecular Sequences                      Pathway
# 33  Genes & Molecular Sequences                    Phenomena
# 34  Genes & Molecular Sequences                   Physiology
# 35  Genes & Molecular Sequences                   Physiology
# 36  Genes & Molecular Sequences                   Physiology
# 37                    Phenomena            Chemicals & Drugs
# 38                    Phenomena  Genes & Molecular Sequences
# 39                   Physiology            Chemicals & Drugs
#
#             het_etype   count
# 0       EXPRESSES_AeG  526407
# 1   DOWNREGULATES_AdG  102240
# 2     UPREGULATES_AuG   97848
# 3         CAUSES_CcSE      36
# 4       RESEMBLES_CrC    6486
# 5       INCLUDES_PCiC     920
# 6         CAUSES_CcSE  137458
# 7   DOWNREGULATES_CdG   21102
# 8     UPREGULATES_CuG   18756
# 9           BINDS_CbG   11571
# 10        CAUSES_CcSE     164
# 11      RESEMBLES_CrC       3
# 12        CAUSES_CcSE    1286
# 13      LOCALIZES_DlA    3602
# 14      INCLUDES_PCiC       1
# 15       PRESENTS_DpS    3307
# 16      RESEMBLES_DrD     543
# 17      LOCALIZES_DlA      23
# 18     ASSOCIATES_DaG   12623
# 19    UPREGULATES_DuG    7731
# 20  DOWNREGULATES_DdG    7623
# 21      EXPRESSES_AeG      25
# 22       PRESENTS_DpS      71
# 23      LOCALIZES_DlA       7
# 24  PARTICIPATES_GpCC   73542
# 25  PARTICIPATES_GpBP     159
# 26  PARTICIPATES_GpMF       6
# 27  PARTICIPATES_GpBP    1442
# 28      REGULATES_GrG  265672
# 29      INTERACTS_GiG  147164
# 30       COVARIES_GcG   61690
# 31  PARTICIPATES_GpCC      12
# 32  PARTICIPATES_GpPW   84372
# 33  PARTICIPATES_GpBP    4087
# 34  PARTICIPATES_GpBP  555294
# 35  PARTICIPATES_GpMF   97222
# 36  PARTICIPATES_GpCC      12
# 37      RESEMBLES_CrC       1
# 38          BINDS_CbG      43
# 39      INCLUDES_PCiC     108

# %% [markdown]
# ---

# %% [markdown]
# ### standardize Semmed edges with UMLS: tags on node ids

# %%
sedges = (pd
    .read_csv("../semmed/data/edges.tsv", sep='\t')
    .drop(["source_uid", "target_uid"], axis=1)

    .assign(source_cui = lambda df: df["source_id"].map(
        lambda v: "UMLS:{}".format(v) if is_cui(v) else v
    ))
    .assign(target_cui = lambda df: df["target_id"].map(
        lambda v: "UMLS:{}".format(v) if is_cui(v) else v
    ))
    .drop(["source_id", "target_id"], axis=1)
)

# %%
sedges.head()
# Out:
#                 etype     source_cui     target_cui
# 0  REGULATES_CDreg>CD  UMLS:C0000039  UMLS:C0001026
# 1  REGULATES_CDreg>CD  UMLS:C0000039  UMLS:C0001041
# 2  REGULATES_CDreg>CD  UMLS:C0000039  UMLS:C0001492
# 3  REGULATES_CDreg>CD  UMLS:C0000039  UMLS:C0001962
# 4   RELATED_TO_CDrtCD  UMLS:C0000039  UMLS:C0001975

# %%
sedges.shape
# Out:
# (9646780, 3)

# %% [markdown]
# ---

# %% [markdown]
# ### Add in node types for semmed

# %%
sem_etypes = (sedges
    .merge(
        snodes.drop("name", axis=1),
        how="inner", left_on="source_cui", right_on="cui"
    )
    .drop("cui", axis=1)
    .rename(columns={"sem_type": "source_stype"})

    .merge(
        snodes.drop("name", axis=1),
        how="inner", left_on="target_cui", right_on="cui"
    )
    .drop("cui", axis=1)
    .rename(columns={"sem_type": "target_stype"})
)

# %%
sem_etypes.head()
# Out:
#                 etype     source_cui     target_cui       source_stype  \
# 0  REGULATES_CDreg>CD  UMLS:C0000039  UMLS:C0001026  Chemicals & Drugs
# 1  REGULATES_CDreg>CD  UMLS:C0000167  UMLS:C0001026  Chemicals & Drugs
# 2     PRODUCES_LBpdCD  UMLS:C0000901  UMLS:C0001026      Living Beings
# 3  REGULATES_CDreg>CD  UMLS:C0000975  UMLS:C0001026  Chemicals & Drugs
# 4  REGULATES_CDreg>CD  UMLS:C0000977  UMLS:C0001026  Chemicals & Drugs
#
#         target_stype
# 0  Chemicals & Drugs
# 1  Chemicals & Drugs
# 2  Chemicals & Drugs
# 3  Chemicals & Drugs
# 4  Chemicals & Drugs

# %%
sem_etypes.shape
# Out:
# (9646780, 5)

# %% [markdown]
# ---

# %% [markdown]
# ### Group by node type and count edges

# %%
s_etype_count = (sem_etypes
    .groupby(["source_stype", "target_stype"])
    ["etype"]
    .value_counts()
    .to_frame("count")
    .reset_index()
)

# %%
s_etype_count
# Out:
#                    source_stype                 target_stype  \
# 0                       Anatomy                      Anatomy
# 1                       Anatomy            Chemicals & Drugs
# 2                       Anatomy                    Disorders
# 3                       Anatomy  Genes & Molecular Sequences
# 4                       Anatomy                Living Beings
# 5                       Anatomy                Living Beings
# 6                       Anatomy                   Physiology
# 7             Chemicals & Drugs                      Anatomy
# 8             Chemicals & Drugs            Chemicals & Drugs
# 9             Chemicals & Drugs            Chemicals & Drugs
# 10            Chemicals & Drugs  Genes & Molecular Sequences
# 11            Chemicals & Drugs  Genes & Molecular Sequences
# 12            Chemicals & Drugs  Genes & Molecular Sequences
# 13            Chemicals & Drugs                Living Beings
# 14            Chemicals & Drugs                Living Beings
# 15            Chemicals & Drugs                    Phenomena
# 16            Chemicals & Drugs                   Physiology
# 17            Chemicals & Drugs                   Physiology
# 18                    Disorders                    Disorders
# 19                    Disorders                Living Beings
# 20                    Disorders                   Physiology
# 21  Genes & Molecular Sequences                      Anatomy
# 22  Genes & Molecular Sequences                    Disorders
# 23  Genes & Molecular Sequences                    Disorders
# 24  Genes & Molecular Sequences                    Disorders
# 25  Genes & Molecular Sequences  Genes & Molecular Sequences
# 26  Genes & Molecular Sequences  Genes & Molecular Sequences
# 27  Genes & Molecular Sequences                Living Beings
# 28  Genes & Molecular Sequences                    Phenomena
# 29  Genes & Molecular Sequences                   Physiology
# 30                Living Beings            Chemicals & Drugs
# 31                Living Beings                    Disorders
# 32                Living Beings                Living Beings
# 33                Living Beings                Living Beings
# 34                    Phenomena                    Disorders
# 35                    Phenomena                   Physiology
# 36                   Physiology            Chemicals & Drugs
# 37                   Physiology                    Disorders
# 38                   Physiology                Living Beings
# 39                   Physiology                Living Beings
# 40                   Physiology                   Physiology
#
#                      etype   count
# 0         LOCATION_OF_AloA  267214
# 1        LOCATION_OF_AloCD  996348
# 2        LOCATION_OF_AloDO  520885
# 3         LOCATION_OF_AloG  534310
# 4           PART_OF_Apo>LB  133351
# 5        LOCATION_OF_AloLB   36757
# 6        LOCATION_OF_AloPS   29184
# 7            AFFECTS_CDafA  313572
# 8       REGULATES_CDreg>CD  814972
# 9        RELATED_TO_CDrtCD  216035
# 10    INTERACTS_WITH_CDiwG  705394
# 11        STIMULATES_CDstG  373978
# 12          INHIBITS_CDinG  235809
# 13            TREATS_CDtLB  101489
# 14  ADMINISTERED_TO_CDatLB   61085
# 15          AFFECTS_CDafPH   74460
# 16         AUGMENTS_CDagPS  222088
# 17         DISRUPTS_CDdsPS  177044
# 18  ASSOCIATED_WITH_DOawDO  690653
# 19          AFFECTS_DOafLB  450584
# 20            CAUSES_DOcPS   54448
# 21            AFFECTS_GafA  124156
# 22   ASSOCIATED_WITH_GawDO  289269
# 23          AUGMENTS_GagDO  133583
# 24          INHIBITS_GinDO  108862
# 25     INTERACTS_WITH_GiwG  235187
# 26        REGULATES_Greg>G  198435
# 27           PART_OF_GpoLB  205720
# 28           AFFECTS_GafPH   20314
# 29           AFFECTS_GafPS  250457
# 30         PRODUCES_LBpdCD  449085
# 31            CAUSES_LBcDO   47773
# 32              ISA_LBi>LB   72658
# 33   INTERACTS_WITH_LBiwLB   35328
# 34          AFFECTS_PHafDO   33382
# 35          AFFECTS_PHafPS   22460
# 36  ASSOCIATED_WITH_PSawCD   32409
# 37          AFFECTS_PSafDO  135830
# 38     PROCESS_OF_PSpro>LB  126722
# 39          AFFECTS_PSafLB   13999
# 40          AFFECTS_PSafPS  101491

# %% [markdown]
# ---

# %% [markdown]
# ### combine all edges from both networks and manually decide which ones to retain

# %%
res = (h_etype_count
    .rename(columns={
        "start_ftype": "source_stype",
        "end_ftype": "target_stype",
        "het_etype": "etype"
    })
    .assign(orig = "h")
    .append(
        s_etype_count.assign(orig = "semmed")
    )
    .sort_values(
        by=["source_stype", "target_stype", "count"],
        ascending=[True, True, False]
    )
)

# %%
res
# Out:
#                    source_stype                 target_stype  \
# 0                       Anatomy                      Anatomy
# 1                       Anatomy            Chemicals & Drugs
# 2                       Anatomy                    Disorders
# 3                       Anatomy  Genes & Molecular Sequences
# 0                       Anatomy  Genes & Molecular Sequences
# 1                       Anatomy  Genes & Molecular Sequences
# 2                       Anatomy  Genes & Molecular Sequences
# 4                       Anatomy                Living Beings
# 5                       Anatomy                Living Beings
# 6                       Anatomy                   Physiology
# 7             Chemicals & Drugs                      Anatomy
# 3             Chemicals & Drugs                      Anatomy
# 8             Chemicals & Drugs            Chemicals & Drugs
# 9             Chemicals & Drugs            Chemicals & Drugs
# 4             Chemicals & Drugs            Chemicals & Drugs
# 5             Chemicals & Drugs            Chemicals & Drugs
# 6             Chemicals & Drugs                    Disorders
# 10            Chemicals & Drugs  Genes & Molecular Sequences
# 11            Chemicals & Drugs  Genes & Molecular Sequences
# 12            Chemicals & Drugs  Genes & Molecular Sequences
# 7             Chemicals & Drugs  Genes & Molecular Sequences
# 8             Chemicals & Drugs  Genes & Molecular Sequences
# 9             Chemicals & Drugs  Genes & Molecular Sequences
# 13            Chemicals & Drugs                Living Beings
# 14            Chemicals & Drugs                Living Beings
# 15            Chemicals & Drugs                    Phenomena
# 10            Chemicals & Drugs                    Phenomena
# 11            Chemicals & Drugs                    Phenomena
# 16            Chemicals & Drugs                   Physiology
# 17            Chemicals & Drugs                   Physiology
# ..                          ...                          ...
# 24  Genes & Molecular Sequences                    Disorders
# 27  Genes & Molecular Sequences                    Disorders
# 28  Genes & Molecular Sequences  Genes & Molecular Sequences
# 25  Genes & Molecular Sequences  Genes & Molecular Sequences
# 26  Genes & Molecular Sequences  Genes & Molecular Sequences
# 29  Genes & Molecular Sequences  Genes & Molecular Sequences
# 30  Genes & Molecular Sequences  Genes & Molecular Sequences
# 27  Genes & Molecular Sequences                Living Beings
# 31  Genes & Molecular Sequences                Living Beings
# 32  Genes & Molecular Sequences                      Pathway
# 28  Genes & Molecular Sequences                    Phenomena
# 33  Genes & Molecular Sequences                    Phenomena
# 34  Genes & Molecular Sequences                   Physiology
# 29  Genes & Molecular Sequences                   Physiology
# 35  Genes & Molecular Sequences                   Physiology
# 36  Genes & Molecular Sequences                   Physiology
# 30                Living Beings            Chemicals & Drugs
# 31                Living Beings                    Disorders
# 32                Living Beings                Living Beings
# 33                Living Beings                Living Beings
# 37                    Phenomena            Chemicals & Drugs
# 34                    Phenomena                    Disorders
# 38                    Phenomena  Genes & Molecular Sequences
# 35                    Phenomena                   Physiology
# 36                   Physiology            Chemicals & Drugs
# 39                   Physiology            Chemicals & Drugs
# 37                   Physiology                    Disorders
# 38                   Physiology                Living Beings
# 39                   Physiology                Living Beings
# 40                   Physiology                   Physiology
#
#                      etype   count    orig
# 0         LOCATION_OF_AloA  267214  semmed
# 1        LOCATION_OF_AloCD  996348  semmed
# 2        LOCATION_OF_AloDO  520885  semmed
# 3         LOCATION_OF_AloG  534310  semmed
# 0            EXPRESSES_AeG  526407       h
# 1        DOWNREGULATES_AdG  102240       h
# 2          UPREGULATES_AuG   97848       h
# 4           PART_OF_Apo>LB  133351  semmed
# 5        LOCATION_OF_AloLB   36757  semmed
# 6        LOCATION_OF_AloPS   29184  semmed
# 7            AFFECTS_CDafA  313572  semmed
# 3              CAUSES_CcSE      36       h
# 8       REGULATES_CDreg>CD  814972  semmed
# 9        RELATED_TO_CDrtCD  216035  semmed
# 4            RESEMBLES_CrC    6486       h
# 5            INCLUDES_PCiC     920       h
# 6              CAUSES_CcSE  137458       h
# 10    INTERACTS_WITH_CDiwG  705394  semmed
# 11        STIMULATES_CDstG  373978  semmed
# 12          INHIBITS_CDinG  235809  semmed
# 7        DOWNREGULATES_CdG   21102       h
# 8          UPREGULATES_CuG   18756       h
# 9                BINDS_CbG   11571       h
# 13            TREATS_CDtLB  101489  semmed
# 14  ADMINISTERED_TO_CDatLB   61085  semmed
# 15          AFFECTS_CDafPH   74460  semmed
# 10             CAUSES_CcSE     164       h
# 11           RESEMBLES_CrC       3       h
# 16         AUGMENTS_CDagPS  222088  semmed
# 17         DISRUPTS_CDdsPS  177044  semmed
# ..                     ...     ...     ...
# 24          INHIBITS_GinDO  108862  semmed
# 27       PARTICIPATES_GpBP    1442       h
# 28           REGULATES_GrG  265672       h
# 25     INTERACTS_WITH_GiwG  235187  semmed
# 26        REGULATES_Greg>G  198435  semmed
# 29           INTERACTS_GiG  147164       h
# 30            COVARIES_GcG   61690       h
# 27           PART_OF_GpoLB  205720  semmed
# 31       PARTICIPATES_GpCC      12       h
# 32       PARTICIPATES_GpPW   84372       h
# 28           AFFECTS_GafPH   20314  semmed
# 33       PARTICIPATES_GpBP    4087       h
# 34       PARTICIPATES_GpBP  555294       h
# 29           AFFECTS_GafPS  250457  semmed
# 35       PARTICIPATES_GpMF   97222       h
# 36       PARTICIPATES_GpCC      12       h
# 30         PRODUCES_LBpdCD  449085  semmed
# 31            CAUSES_LBcDO   47773  semmed
# 32              ISA_LBi>LB   72658  semmed
# 33   INTERACTS_WITH_LBiwLB   35328  semmed
# 37           RESEMBLES_CrC       1       h
# 34          AFFECTS_PHafDO   33382  semmed
# 38               BINDS_CbG      43       h
# 35          AFFECTS_PHafPS   22460  semmed
# 36  ASSOCIATED_WITH_PSawCD   32409  semmed
# 39           INCLUDES_PCiC     108       h
# 37          AFFECTS_PSafDO  135830  semmed
# 38     PROCESS_OF_PSpro>LB  126722  semmed
# 39          AFFECTS_PSafLB   13999  semmed
# 40          AFFECTS_PSafPS  101491  semmed
#
# [81 rows x 5 columns]

# %%
res.to_csv("edge_merge.tsv", sep='\t', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Edge merge (load in manual curation results)
#
# Edge merging was performed in Excel from the `edge_merge.tsv` file.

# %%
res = (pd
    .read_csv("edge_merge_final.tsv", sep='\t')
    .assign(changed = lambda df: df["etype"] != df["final_etype"])
)

# %%
res.head()
# Out:
#   source_stype                 target_stype              etype   count  \
# 0      Anatomy                      Anatomy   LOCATION_OF_AloA  267214
# 1      Anatomy            Chemicals & Drugs  LOCATION_OF_AloCD  996348
# 2      Anatomy                    Disorders  LOCATION_OF_AloDO  520885
# 3      Anatomy  Genes & Molecular Sequences   LOCATION_OF_AloG  534310
# 4      Anatomy  Genes & Molecular Sequences      EXPRESSES_AeG  526407
#
#      orig        final_etype  changed
# 0  semmed   LOCATION_OF_AloA    False
# 1  semmed  LOCATION_OF_AloCD    False
# 2  semmed  LOCATION_OF_AloDO    False
# 3  semmed      EXPRESSES_AeG     True
# 4       h      EXPRESSES_AeG    False

# %%
res.shape
# Out:
# (81, 7)

# %%
res["changed"].value_counts()
# Out:
# False    44
# True     37
# Name: changed, dtype: int64

# %%
res.groupby(["changed", "orig"]).size()
# Out:
# changed  orig
# False    h          4
#          semmed    40
# True     h         36
#          semmed     1
# dtype: int64

# %% [markdown]
# Around half of the edges were untouched, and those which were changed were mostly hetionet edges (since we're trying to map onto semmeddb).

# %% [markdown]
# ---

# %% [markdown]
# ## Final concatenation of edges with provenance

# %%
fhedges = (hedges
    # convert source node ids
    .merge(
        fin_hnode_map[["hetio_id", "final_id", "fin_type"]],
        how="inner", left_on="start_id", right_on="hetio_id"
    )
    .drop(["start_id", "hetio_id"], axis=1)
    .rename(columns={
        "final_id": "source_fid",
        "fin_type": "source_stype"
    })
     
    # convert target node ids
    .merge(
        fin_hnode_map[["hetio_id", "final_id", "fin_type"]],
        how="inner", left_on="end_id", right_on="hetio_id"
    )
    .drop(["end_id", "hetio_id"], axis=1)
    .rename(columns={
        "final_id": "target_fid",
        "fin_type": "target_stype"
    })
     
    .rename(columns={"het_etype": "etype"})

    # change edge types
    .merge(
        (res
            .query("final_etype != 'delete'")
            [["source_stype", "target_stype", "etype", "final_etype"]]
        ),
        how="inner", on=["source_stype", "target_stype", "etype"]
    )
    .drop("etype", axis=1)
     
    .assign(origin = "hetionet")
    .drop_duplicates()
    .reset_index(drop=True)
)

# %%
fhedges.head()
# Out:
#       source_fid                 source_stype  target_fid target_stype  \
# 0  UMLS:C1857700  Genes & Molecular Sequences  GO:0042254   Physiology
# 1  UMLS:C1419751  Genes & Molecular Sequences  GO:0042254   Physiology
# 2  UMLS:C1335641  Genes & Molecular Sequences  GO:0042254   Physiology
# 3  UMLS:C1419752  Genes & Molecular Sequences  GO:0042254   Physiology
# 4  UMLS:C1422367  Genes & Molecular Sequences  GO:0042254   Physiology
#
#      final_etype    origin
# 0  AFFECTS_GafPS  hetionet
# 1  AFFECTS_GafPS  hetionet
# 2  AFFECTS_GafPS  hetionet
# 3  AFFECTS_GafPS  hetionet
# 4  AFFECTS_GafPS  hetionet

# %%
fhedges.shape
# Out:
# (2647687, 6)

# %% [markdown]
# ---

# %% [markdown]
# ## Final results and write to file

# %%
merged_network = (sedges
    .merge(
        snodes.drop("name", axis=1),
        how="inner", left_on="source_cui", right_on="cui"
    )
    .drop("cui", axis=1)
    .rename(columns={"sem_type": "source_stype"})

    .merge(
        snodes.drop("name", axis=1),
        how="inner", left_on="target_cui", right_on="cui"
    )
    .drop("cui", axis=1)
    .rename(columns={"sem_type": "target_stype"})

    .rename(columns={
        "source_cui": "source_fid",
        "target_cui": "target_fid",
        "etype": "final_etype"
    })
    .assign(origin = "semmeddb")
                  
    .append(fhedges)
    .reset_index(drop=True)
)

# %%
merged_network.head()
# Out:
#           final_etype    origin     source_fid       source_stype  \
# 0  REGULATES_CDreg>CD  semmeddb  UMLS:C0000039  Chemicals & Drugs
# 1  REGULATES_CDreg>CD  semmeddb  UMLS:C0000167  Chemicals & Drugs
# 2     PRODUCES_LBpdCD  semmeddb  UMLS:C0000901      Living Beings
# 3  REGULATES_CDreg>CD  semmeddb  UMLS:C0000975  Chemicals & Drugs
# 4  REGULATES_CDreg>CD  semmeddb  UMLS:C0000977  Chemicals & Drugs
#
#       target_fid       target_stype
# 0  UMLS:C0001026  Chemicals & Drugs
# 1  UMLS:C0001026  Chemicals & Drugs
# 2  UMLS:C0001026  Chemicals & Drugs
# 3  UMLS:C0001026  Chemicals & Drugs
# 4  UMLS:C0001026  Chemicals & Drugs

# %%
merged_network.sample(10)
# Out:
#                    final_etype    origin     source_fid  \
# 4291225         AUGMENTS_GagDO  semmeddb  UMLS:C0033713
# 11105071       UPREGULATES_AuG  hetionet  UMLS:C0027088
# 11268139     DOWNREGULATES_AdG  hetionet  UMLS:C0042993
# 10295667         EXPRESSES_AeG  hetionet  UMLS:C0935625
# 233522          INHIBITS_CDinG  semmeddb  UMLS:C1120843
# 3353937   INTERACTS_WITH_CDiwG  semmeddb  UMLS:C0017950
# 3043797       STIMULATES_CDstG  semmeddb  UMLS:C0085301
# 8036146         INHIBITS_GinDO  semmeddb  UMLS:C1335265
# 10139357         AFFECTS_GafPS  hetionet  UMLS:C1857782
# 2163903          AFFECTS_CDafA  semmeddb  UMLS:C0065264
#
#                          source_stype     target_fid  \
# 4291225   Genes & Molecular Sequences  UMLS:C0205698
# 11105071                      Anatomy  UMLS:C1539800
# 11268139                      Anatomy  UMLS:C1538353
# 10295667                      Anatomy  UMLS:C1538580
# 233522              Chemicals & Drugs  UMLS:C1366557
# 3353937             Chemicals & Drugs  UMLS:C1442864
# 3043797             Chemicals & Drugs  UMLS:C1419038
# 8036146   Genes & Molecular Sequences  UMLS:C0339467
# 10139357  Genes & Molecular Sequences     GO:1900246
# 2163903             Chemicals & Drugs  UMLS:C0014597
#
#                          target_stype
# 4291225                     Disorders
# 11105071  Genes & Molecular Sequences
# 11268139  Genes & Molecular Sequences
# 10295667  Genes & Molecular Sequences
# 233522    Genes & Molecular Sequences
# 3353937   Genes & Molecular Sequences
# 3043797   Genes & Molecular Sequences
# 8036146                     Disorders
# 10139357                   Physiology
# 2163903                       Anatomy

# %%
merged_network.shape
# Out:
# (12294467, 6)

# %%
merged_network["origin"].value_counts()
# Out:
# semmeddb    9646780
# hetionet    2647687
# Name: origin, dtype: int64

# %%
merged_network["source_fid"].nunique()
# Out:
# 187319

# %%
merged_network["target_fid"].nunique()
# Out:
# 178642

# %% [markdown]
# ### number of edges shared by both networks

# %%
(merged_network
    .query("origin == 'semmeddb'")
    [["source_fid", "target_fid", "final_etype"]]
    .merge(
        merged_network.query("origin == 'hetionet'")[["source_fid", "target_fid", "final_etype"]],
        how="inner", on=["source_fid", "target_fid", "final_etype"]
    )
    .drop_duplicates()
    .shape
)
# Out:
# (27725, 3)

# %% [markdown]
# ---

# %%
fin_nodes = (fin_hnode_map
    .query("~in_sem")
    [["final_id", "name", "fin_type"]]
    .assign(origin = "hetionet")
    .rename(columns={
        "final_id": "node_id",
        "fin_type": "sem_type"
    })
     
    .append(
        snodes.assign(origin = "semmeddb")
        .rename(columns={"cui": "node_id"})
    )
    .reset_index(drop=True)
)

# %%
fin_nodes.shape
# Out:
# (231543, 4)

# %%
fin_nodes.head()
# Out:
#       name    node_id    origin                     sem_type
# 0  GAGE12F  100008586  hetionet  Genes & Molecular Sequences
# 1     DUXB  100033411  hetionet  Genes & Molecular Sequences
# 2     DDTL  100037417  hetionet  Genes & Molecular Sequences
# 3    OCTN3  100049579  hetionet  Genes & Molecular Sequences
# 4  POM121C  100101267  hetionet  Genes & Molecular Sequences

# %%
fin_nodes["node_id"].nunique()
# Out:
# 231543

# %%
fin_nodes["origin"].value_counts()
# Out:
# semmeddb    210389
# hetionet     21154
# Name: origin, dtype: int64

# %%
fin_nodes["sem_type"].value_counts()
# Out:
# Chemicals & Drugs              81308
# Living Beings                  48191
# Disorders                      38191
# Genes & Molecular Sequences    25453
# Physiology                     19308
# Anatomy                        16135
# Pathway                         1822
# Phenomena                       1135
# Name: sem_type, dtype: int64

# %% [markdown]
# ---

# %%
fin_nodes.to_csv("merged_network/nodes.tsv", sep='\t', index=False)

# %%
merged_network.to_csv("merged_network/edges.tsv", sep='\t', index=False)
